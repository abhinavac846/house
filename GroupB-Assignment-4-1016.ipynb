# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Heart.csv')

# %%
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
dataFrame = df.drop(['Unnamed: 0'],axis=1)

# %%
dataFrame.head()
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1       typical     145   233    1        2    150      0      2.3
# 1   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 2   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 3   37    1    nonanginal     130   250    0        0    187      0      3.5
# 4   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 0      3  0.0       fixed   No
# 1      2  3.0      normal  Yes
# 2      2  2.0  reversable  Yes
# 3      3  0.0      normal   No
# 4      1  0.0      normal   No

# %%
dataFrame.tail()
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 298      1.2      2  0.0  reversable  Yes
# 299      3.4      2  2.0  reversable  Yes
# 300      1.2      2  1.0  reversable  Yes
# 301      0.0      2  1.0      normal  Yes
# 302      0.0      1  NaN      normal   No

# %%
sns.scatterplot(dataFrame)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=dataFrame, x="Age", y="RestBP", hue="AHD")
# Out:
# <Axes: xlabel='Age', ylabel='RestBP'>

# %%
sns.scatterplot(data=dataFrame, x="Age", y="Chol", hue="AHD")
# Out:
# <Axes: xlabel='Age', ylabel='Chol'>

# %%
sns.scatterplot(data=dataFrame, x="RestBP", y="MaxHR", hue="AHD")
# Out:
# <Axes: xlabel='RestBP', ylabel='MaxHR'>

# %%
sns.scatterplot(data=dataFrame, x="MaxHR", y="Age", hue="AHD")
# Out:
# <Axes: xlabel='MaxHR', ylabel='Age'>

# %%
sns.scatterplot(data=dataFrame, x="Chol", y="Oldpeak", hue="AHD")
# Out:
# <Axes: xlabel='Chol', ylabel='Oldpeak'>

# %%
sns.scatterplot(data=dataFrame, x="Oldpeak", y="RestBP", hue="AHD")
# Out:
# <Axes: xlabel='Oldpeak', ylabel='RestBP'>

# %%
pd.plotting.scatter_matrix(dataFrame, alpha=0.2, figsize=(10,10))
# Out:
# array([[<Axes: xlabel='Age', ylabel='Age'>,
#         <Axes: xlabel='Sex', ylabel='Age'>,
#         <Axes: xlabel='RestBP', ylabel='Age'>,
#         <Axes: xlabel='Chol', ylabel='Age'>,
#         <Axes: xlabel='Fbs', ylabel='Age'>,
#         <Axes: xlabel='RestECG', ylabel='Age'>,
#         <Axes: xlabel='MaxHR', ylabel='Age'>,
#         <Axes: xlabel='ExAng', ylabel='Age'>,
#         <Axes: xlabel='Oldpeak', ylabel='Age'>,
#         <Axes: xlabel='Slope', ylabel='Age'>,
#         <Axes: xlabel='Ca', ylabel='Age'>],
#        [<Axes: xlabel='Age', ylabel='Sex'>,
#         <Axes: xlabel='Sex', ylabel='Sex'>,
#         <Axes: xlabel='RestBP', ylabel='Sex'>,
#         <Axes: xlabel='Chol', ylabel='Sex'>,
#         <Axes: xlabel='Fbs', ylabel='Sex'>,
#         <Axes: xlabel='RestECG', ylabel='Sex'>,
#         <Axes: xlabel='MaxHR', ylabel='Sex'>,
#         <Axes: xlabel='ExAng', ylabel='Sex'>,
#         <Axes: xlabel='Oldpeak', ylabel='Sex'>,
# ...

# %%
sns.kdeplot(data=dataFrame)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=dataFrame, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=dataFrame, x='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='Density'>

# %%
sns.kdeplot(data=dataFrame, x='RestBP')
# Out:
# <Axes: xlabel='RestBP', ylabel='Density'>

# %%
sns.kdeplot(data=dataFrame, x='Chol')
# Out:
# <Axes: xlabel='Chol', ylabel='Density'>

# %%
sns.kdeplot(data=dataFrame, x='Fbs')
# Out:
# <Axes: xlabel='Fbs', ylabel='Density'>

# %%
sns.kdeplot(data=dataFrame, x='RestECG')
# Out:
# <Axes: xlabel='RestECG', ylabel='Density'>

# %%
sns.boxplot(x=dataFrame["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x=dataFrame["Oldpeak"])
# Out:
# <Axes: xlabel='Oldpeak'>

# %%
sns.boxplot(x=dataFrame["Chol"])
# Out:
# <Axes: xlabel='Chol'>

# %%
sns.boxplot(x=dataFrame["RestBP"])
# Out:
# <Axes: xlabel='RestBP'>

# %%
sns.boxplot(x=dataFrame["RestECG"])
# Out:
# <Axes: xlabel='RestECG'>

# %%
sns.boxplot(x=dataFrame["Sex"])
# Out:
# <Axes: xlabel='Sex'>

# %%
sns.violinplot(x=dataFrame["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(x=dataFrame["Sex"])
# Out:
# <Axes: xlabel='Sex'>

# %%
sns.violinplot(x=dataFrame["RestBP"])
# Out:
# <Axes: xlabel='RestBP'>

# %%
sns.violinplot(x=dataFrame["Chol"])
# Out:
# <Axes: xlabel='Chol'>

# %%
sns.barplot(x=dataFrame['ChestPain'],y=dataFrame['Age'], hue=dataFrame['AHD'])
# Out:
# <Axes: xlabel='ChestPain', ylabel='Age'>

# %%
sns.barplot(x=dataFrame['Thal'],y=dataFrame['Age'], hue=dataFrame['Sex'])
# Out:
# <Axes: xlabel='Thal', ylabel='Age'>

# %%
sns.barplot(x=dataFrame['Thal'],y=dataFrame['Slope'], hue=dataFrame['Sex'])
# Out:
# <Axes: xlabel='Thal', ylabel='Slope'>

# %%
sns.barplot(x=dataFrame['RestECG'],y=dataFrame['Age'], hue=dataFrame['Sex'])
# Out:
# <Axes: xlabel='RestECG', ylabel='Age'>

# %%
sns.countplot(data=dataFrame, x=dataFrame['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(data=dataFrame, x=dataFrame['ChestPain'])
# Out:
# <Axes: xlabel='ChestPain', ylabel='count'>

# %%
sns.countplot(data=dataFrame, x=dataFrame['RestECG'])
# Out:
# <Axes: xlabel='RestECG', ylabel='count'>

# %%
sns.countplot(data=dataFrame, x=dataFrame['ExAng'])
# Out:
# <Axes: xlabel='ExAng', ylabel='count'>

# %%
sns.countplot(data=dataFrame, x=dataFrame['Slope'])
# Out:
# <Axes: xlabel='Slope', ylabel='count'>

# %%
sns.histplot(data=dataFrame,x=dataFrame['Age'], hue='AHD')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=dataFrame,x=dataFrame['Sex'], hue='AHD')
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %%
sns.histplot(data=dataFrame,x=dataFrame['ChestPain'], hue='AHD')
# Out:
# <Axes: xlabel='ChestPain', ylabel='Count'>

# %%
sns.histplot(data=dataFrame,x=dataFrame['RestBP'], hue='AHD')
# Out:
# <Axes: xlabel='RestBP', ylabel='Count'>

# %%
dataFrame.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>, <Axes: title={'center': 'Sex'}>,
#         <Axes: title={'center': 'RestBP'}>],
#        [<Axes: title={'center': 'Chol'}>,
#         <Axes: title={'center': 'Fbs'}>,
#         <Axes: title={'center': 'RestECG'}>],
#        [<Axes: title={'center': 'MaxHR'}>,
#         <Axes: title={'center': 'ExAng'}>,
#         <Axes: title={'center': 'Oldpeak'}>],
#        [<Axes: title={'center': 'Slope'}>,
#         <Axes: title={'center': 'Ca'}>, <Axes: >]], dtype=object)

# %%
dataFrame['Age'].hist()
# Out:
# <Axes: >

# %%
sns.pairplot(dataFrame)

# %%
sns.lineplot(x=dataFrame['Age'],y=dataFrame['Ca'],hue=dataFrame['AHD'])
# Out:
# <Axes: xlabel='Age', ylabel='Ca'>

# %%
sns.lineplot(x=dataFrame['RestBP'],y=dataFrame['RestECG'],hue=dataFrame['AHD'])
# Out:
# <Axes: xlabel='RestBP', ylabel='RestECG'>

# %%
sns.lineplot(x=dataFrame['Sex'],y=dataFrame['Age'],hue=dataFrame['AHD'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
val = dataFrame['ChestPain'].value_counts()
val
# Out:
# asymptomatic    144
# nonanginal       86
# nontypical       50
# typical          23
# Name: ChestPain, dtype: int64

# %%
colors= ['red', 'green','brown','grey'];
plt.pie([len('asymptomatic'),len('nonanginal'),len('nontypical'),len('typical')],labels=['asymptomatic','nonanginal','nontypical','typical'],colors=colors,autopct='%1.1f%%')
plt.legend()

# %%
val = dataFrame['Thal'].value_counts()
val
# Out:
# normal        166
# reversable    117
# fixed          18
# Name: Thal, dtype: int64

# %%
colors= ['#0075a4', '#bfe8ff','#72adcf','grey'];
plt.pie([len('normal'),len('reversable'),len('fixed')],labels=['normal','reversable','fixed'],colors=colors,autopct='%1.1f%%')
plt.legend()

# %%
val= dataFrame['AHD'].value_counts()
val
# Out:
# No     164
# Yes    139
# Name: AHD, dtype: int64

# %%
colors= ['#0075a4','grey'];
plt.pie([len('Yes'),len('No')],labels=['Yes','No9'],colors=colors,autopct='%1.1f%%')
plt.legend()

# %%
val= dataFrame['Slope'].value_counts()
val
# Out:
# 1    142
# 2    140
# 3     21
# Name: Slope, dtype: int64

# %%
colors= ['#0075a4', '#bfe8ff','grey'];
plt.pie([len('1'),len('2'),len('3')],labels=['1','2','3'],colors=colors,autopct='%1.1f%%')
plt.legend()
